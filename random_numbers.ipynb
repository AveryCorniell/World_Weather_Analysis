# %%
# 6.1.4 Generate Random Latitudes and Longitudes
# Must generate enough coordinates to have a good covering of common travel destinations
# choose coordinates close to a city.
# Approximately 500 ciies is the final amount.
# HELPFUL FACTS!
    # Earth's surface is covered by 70% water while the rest is covered by land.
        # -safe to say that 70% of the latitude and longitude coordinates generated are positioned over some type water body.
    # Seven continents(landmasses) make up only 30% of the Earth's surface.
        # -of that 30% due to hostile terrain, vast mountains, and impenetrable jungles, 
        # some land is vacant or sparsely populated.
# 1. Begin with at least 1,500 latitudes and longitudes (500 divided by 0.3(30% land mass) equals 1,666 lats and longs)
# 2. Generate random lats and longs to check the fair distribution of coordinates around the world.
    # code an algorithm to pick random numbers between the low and high values for lats and longs
    # lats and longs must be floats (angular units(degrees, minutes, seconds) can be expressed with a decimal)
# 3. Use Python "random()" module to generate random numbers...does not need to be installed...part of Python / Anaconda package
# 4. Retrieve a list of available "random()" module functions by typing "random." in a cell and pressing tab
    # will use "randint()", "random()", "randrange()", and "uniform()" functions for testing purposes
    # "randint()" is short for "random integer"

# %%
# Import the random module.
import random

# %%
# Test: ".randint()" returns a single integer between -90 and 90; not useful(by itself) for this project of code
random.randint(-90, 90)
# Out:
# 50

# %%
# Test: ".random()" returns a single floating-point decimal number between 0 and 1.0 
random.random()
# Out:
# 0.9668493013063989

# %%
# Test: combine the two previous functions to generate a random floating-point decimal to get random latitude
    # change the lower point of the "randint()" to 89 to generate random latitudes between -89.99999 and 89.99999

# %% [markdown]
# Using the two functions together, write an algorithm to generate ten random floating-point decimal lats between -90 and 89:
#
# - Assign the variable x to 1.
# - Initialize an empty list, latitudes.
# - We create a while loop where we generate a random latitude and add it to the list.
# - After the random latitude is added to the list we add one to the variable "x".
# - The while loop condition is checked again and will continue to run as long as x is less than 11.

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1
latitudes
# Out:
# [-69.56563637761343,
#  27.837829733759403,
#  -50.21269709027446,
#  45.20508481700566,
#  -16.506802800078813,
#  -49.83141346741092,
#  28.811751641144316,
#  60.58757998489625,
#  -11.501675902953826,
#  -35.03987734872845]

# %%
# Test: ".uniform()" function returns a floating-point decimal number between two given numbers inside the parentheses.
random.uniform(-90, 90)
# Out:
# -11.833741979032922

# %% [markdown]
# Random Functions' Outputs and Limitations Chart
# ![random_functions_chart.png](attachment:random_functions_chart.png)

# %%
# One way to generate more than a thousand latitudes and longitudes is to chain the "NumPy" module to create an array of
#      latitudes and longitudes between the lowest and highest values...
#      -90 and 90 degrees and -180 and 180 degrees respectively
    #Use the ".uniform()" function from the "random" module.

# Import the NumPy module.
import numpy as np

# %%
# Use the ".uniform()" to generate a random floating-point decimal.
np.random.uniform(-90.000, 90.000)
# Out:
# 55.86710224895555

# %%
# Using the "NumPy" module with the "random.uniform()" the parenthical parameters contain
#      lower(low value) and upper(high value) boundaries that are floating-point numbers.
    # can be written like this np.random.uniform(low=-90, high=90).

# To generate more than one floating-point decimal number between -90 and 90, add the "size" parameter when using
#      NumPy module and set that equal to any whole number.

# Test 
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ 42.63983242, -44.97516113, -67.06881805, -51.8363718 ,
#         28.01701252, -59.42069658, -81.55071339, -60.60374964,
#         -5.09404063,  40.82499147, -18.22652071,  17.73427737,
#        -58.63570645, -61.42328459,  60.00141959,  52.17777462,
#        -37.82861438, -26.19050887, -29.47245338,  69.59019583,
#         19.29701265,  66.29873078, -37.95948173,  58.16189125,
#        -32.49858017, -56.28072313, -84.68299588, -27.94290814,
#         20.09572643,  75.69369021,  72.34050469, -68.31813747,
#         56.70848257,  28.60529081, -43.71804538, -47.8846912 ,
#        -38.17623531,  20.74280795,  31.34533512, -21.214247  ,
#         83.25348828, -45.97709658,  39.41713197,  33.00611988,
#        -73.94381415,  89.01792792, -40.70971477,  17.78487685,
#         59.46180887, -49.65546733])

# %%
# Next is to increase the parameter size to 1,500 and test to see if it is faster than the while loop using the
#      "%timeit" magic command.

# Import timeit.
import timeit

# %%
# Add the ""%timeit" magic command before the np.random.uniform(-90.000, 90.000, size=1500)
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 8.86 µs ± 17.9 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# Timing the while loop
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 940 µs ± 8.14 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Using the np.random.uniform(-90.000, 90.000, size=1500) is 100 times faster than using the function.
    # code uses only one line
    # function uses 8 lines

# %%
# Skill Drill: Refactor code for previous while loop to generate 1500 latitudes.
#def latitudes(size = 1500):
x = 0
latitudes = []
while x < (1500):
    random_lat = random.randint(-90, 90) + random.random()
    latitudes.append(random_lat)
    x += 1
latitudes
# Out:
# [34.714012594766345,
#  24.885719004419848,
#  -46.60486103145452,
#  -60.98543330210539,
#  46.88676552875106,
#  -46.49431303159188,
#  55.51368437564183,
#  -76.59750633583086,
#  71.52006694846347,
#  70.9915917816954,
#  -48.959165374217584,
#  -51.76038458232139,
#  -89.66807706519778,
#  48.26106399547646,
#  82.56027774465535,
#  -59.95718061487054,
#  26.83057250285971,
#  61.37955365067513,
#  84.73573955212933,
#  60.9460174646191,
#  31.66756421318435,
#  0.6717403275988053,
#  68.05299752210051,
#  41.32018248536129,
#  -39.70977439074241,
#  24.931140891258803,
#  -70.11973161592971,
#  1.5325048197059365,
#  -60.64299093448871,
#  28.840050721502106,
#  -43.04955630444072,
#  -18.518180928965265,
#  21.413888869829986,
#  -9.066522531134762,
#  37.03050799531848,
#  -73.04567173218446,
#  -29.197856466730915,
#  -0.8748849534940306,
#  85.35516654481765,
#  30.49608720944429,
#  -37.776796452648625,
#  -54.65360870015621,
#  56.39196776869211,
#  -64.26779962693537,
# ...
